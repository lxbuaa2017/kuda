# %% [markdown]
# # neo4j

# %% [markdown]
# 引入neo4j实现知识存储。下载地址：https://neo4j.com/download-center/#releases

# %%
# !pip install py2neo
# Out:
# ...
#      |████████████████████████████████| 71 kB 5.1 kB/s eta 0:00:03
# ...
#      |████████████████████████████████| 81 kB 42 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 183 kB 117 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 340 kB 290 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 849 kB 713 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 839 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 118 kB 1.3 MB/s eta 0:00:01
# ...
#   Created wheel for py2neo: filename=py2neo-4.3.0-py2.py3-none-any.whl size=88305 sha256=baf0fe54fee15840ccc550fbed144903b161877a3e9d44d8b1d6287f1b5e728a
#   Stored in directory: /home/vincent/.cache/pip/wheels/6a/77/bb/46b430c5bc5f69567fee5b2cc0bffff30dd488e1e187b4a28a
# ...
#   Created wheel for neobolt: filename=neobolt-1.7.17-py3-none-any.whl size=37180 sha256=a32102e4f432f7e8b86fbbf0460cf8fc3eba12281f68e8140badfeb072e926b7
# ...

# %%
# !/home/lx/neo4j-community-4.0.3/bin/neo4j console
# Out:
# Directories in use:
#   home:         /home/lx/neo4j-community-4.0.3
#   config:       /home/lx/neo4j-community-4.0.3/conf
#   logs:         /home/lx/neo4j-community-4.0.3/logs
#   plugins:      /home/lx/neo4j-community-4.0.3/plugins
#   import:       /home/lx/neo4j-community-4.0.3/import
#   data:         /home/lx/neo4j-community-4.0.3/data
#   certificates: /home/lx/neo4j-community-4.0.3/certificates
#   run:          /home/lx/neo4j-community-4.0.3/run
# Starting Neo4j.
# 2020-04-30 20:10:32.134+0000 INFO  ======== Neo4j 4.0.3 ========
# 2020-04-30 20:10:32.142+0000 INFO  Starting...
# 2020-04-30 20:10:36.298+0000 INFO  Bolt enabled on localhost:7687.
# 2020-04-30 20:10:36.299+0000 INFO  Started.
# 2020-04-30 20:10:37.697+0000 INFO  Remote interface available at http://localhost:7474/

# %% [markdown]
# # Linux下解决matplot字体问题

# %% [markdown]
# 下载ttf字体到/home/lx/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/font下面，然后修改matplotlibrc文件，再清除缓存即可。

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /home/lx/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
# mv  .ttf /home/lx/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf
rm -rf /home/lx/.cache/matplotlib

# %% [markdown]
# 知识图谱可视化部分默认支持字体SimHei,大多数环境下的matplotlib不支持中文字体, 我们提供字体包的下载链接; 您可以通过运行以下代码, 将Simhei字体加载入matplotlib字体库

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
## 设置字体
font_dirs = ['simhei/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)
plt.rcParams['font.family'] = "SimHei"

# %% [markdown]
# # 读取docx

# %%
import docx
path = "docx/公共基础复习资料.docx"
file = docx.Document(path)
article=""
for p in file.paragraphs:
    article+=p.text
with open('txt/公共基础复习资料.txt','w') as f:
    f.write(article)

# %% [markdown]
# # 分句

# %% [markdown]
# 存在的问题：
#
# 1.换行需合理去除。如这里，即使是去掉了换行符，也只会变成“二叉树的遍历（1）前序遍历（DLR）......”这样，分句很难分准。考虑在标题加个“:”看看效果。
# 二叉树的遍历
# （1）前序遍历（DLR），首先访问根结点，然后遍历左子树，最后遍历右子树；
# （2）中序遍历（LDR），首先遍历左子树，然后访问根结点，最后遍历右子树；
# （3）后序遍历（LRD）首先遍历左子树，然后访问遍历右子树，最后访问根结点。
#
#
# 2.怎么把大标题和子标题联系起来，特别是子标题有时候还没有数字序号
# 如：
# 1．7 查找技术
# 顺序查找的使用情况：
# （1）线性表为无序表；
# （2）表采用链式存储结构。
# 二分法查找只适用于顺序存储的有序表，对于长度为n的有序线性表，最坏情况只需比较log2n次。
# 怎么组成“顺序查找，是，查找技术”，“二分法查找，是，查找技术”的三元组？

# %%
import smoothnlp
from smoothnlp import kg
txt = ""
with open('txt/公共基础复习资料.txt','r') as f:
    txt += f.read()
# txt.strip('\r')
# txt.strip('\n')
txt.replace('\r',"")
txt.replace('\n',"")
txt.replace(' ','')
print(txt)
strs = smoothnlp.split2sentences(txt)
# for string in strs:
#     print(string+'\n')
# Out:
# 二级公共基础知识总结
# 第一章 数据结构与算法
# 1.1 算法
# 算法：是指解题方案的准确而完整的描述。
# 算法不等于程序，也不等计算机方法，程序的编制不可能优于算法的设计。
# 算法的基本特征：是一组严谨地定义运算顺序的规则，每一个规则都是有效的，是明确的，此顺序将在有限的次数下终止。特征包括：
# （1）可行性；
# （2）确定性，算法中每一步骤都必须有明确定义，不充许有模棱两可的解释，不允许有多义性；
# （3）有穷性，算法必须能在有限的时间内做完，即能在执行有限个步骤后终止，包括合理的执行时间的含义；
# （4）拥有足够的情报。
# 算法的基本要素：一是对数据对象的运算和操作；二是算法的控制结构。
# 指令系统：一个计算机系统能执行的所有指令的集合。
# 基本运算包括：算术运算、逻辑运算、关系运算、数据传输。
# 算法的控制结构：顺序结构、选择结构、循环结构。
# 算法基本设计方法：列举法、归纳法、递推、递归、减斗递推技术、回溯法。
# 算法复杂度：算法时间复杂度和算法空间复杂度。
# 算法时间复杂度是指执行算法所需要的计算工作量。
# 算法空间复杂度是指执行这个算法所需要的内存空间。
# 1.2 数据结构的基本基本概念
# 数据结构研究的三个方面：
# （1）数据集合中各数据元素之间所固有的逻辑关系，即数据的逻辑结构；
# （2）在对数据进行处理时，各数据元素在计算机中的存储关系，即数据的存储结构；
# （3）对各种数据结构进行的运算。
# 数据结构是指相互有关联的数据元素的集合。
# 数据的逻辑结构包含：
# （1）表示数据元素的信息；
# （2）表示各数据元素之间的前后件关系。
# 数据的存储结构有顺序、链接、索引等。
# 线性结构条件：
# （1）有且只有一个根结点；
# （2）每一个结点最多有一个前件，也最多有一个后件。
# 非线性结构：不满足线性结构条件的数据结构。
# 1．3 线性表及其顺序存储结构
# 线性表是由一组数据元素构成，数据元素的位置只取决于自己的序号，元素之间的相对位置是线性的。
# 在复杂线性表中，由若干项数据元素组成的数据元素称为记录，而由多个记录构成的线性表又称为文件。
# 非空线性表的结构特征：
# （1）且只有一个根结点a1，它无前件；
# （2）有且只有一个终端结点an，它无后件；
# ...

# %%
rels = kg.extract(strs)  ## 调用SmoothNLP解析
print(rels)
# g = kg.rel2graph(rels)  ## 依据文本解析结果, 生成networkx有向图
# fig = kg.graph2fig(g,x=20000,y=20000)  ## 生成 matplotlib.figure.Figure 图片
# fig.savefig("公共基础复习资料.png") ## 保存图片到PNG
# Out:
# [{'_conf_score': 0.41557023, 'action': '是指', 'object': '完整的描述', 'subject': '算法：', 'type': 'action'}, {'_conf_score': 0.41557023, 'action': '是指', 'object': '解题方案', 'subject': '算法：', 'type': 'action'}, {'_conf_score': 0.5452929, 'action': '不可能优于', 'object': '算法的设计', 'subject': '程序的编制', 'type': 'action'}, {'_conf_score': 0.507533, 'action': '都必须有', 'object': '明确定义', 'subject': '算法中每一步骤', 'type': 'action'}, {'_conf_score': 0.4241477, 'action': '都必须有', 'object': '确定性', 'subject': '算法中每一步骤', 'type': 'state'}, {'_conf_score': 0.41979942, 'action': '是', 'object': '对数据对象的运算和操作', 'subject': '算法的基本要素：', 'type': 'state'}, {'_conf_score': 0.41979942, 'action': '是', 'object': '算法的控制结构', 'subject': '算法的基本要素：', 'type': 'state'}, {'_conf_score': 0.48183978, 'action': '包括', 'object': '算术运算、逻辑运算、关系运算、数据传输', 'subject': '基本运算', 'type': 'action'}, {'_conf_score': 0.38296872, 'action': '选择', 'object': '结构、循环结构', 'subject': '顺序结构、', 'type': 'action'}, {'_conf_score': 0.51243323, 'action': '是指执行', 'object': 
# ...

# %% [markdown]
# 可以考虑用create添加，但是很慢

# %% [markdown]
# ## py2neo示例

# %%
#coding:utf-8
from py2neo import Graph,Node,Relationship
 
##连接neo4j数据库，输入地址、用户名、密码
graph = Graph('http://localhost:7474',username='neo4j',password='kuda')
 
##创建结点
test_node_1 = Node(label='ru_yi_zhuan',name='皇帝')
test_node_2 = Node(label='ru_yi_zhuan',name='皇后')
test_node_3 = Node(label='ru_yi_zhuan',name='公主')
graph.create(test_node_1)
graph.create(test_node_2)
graph.create(test_node_3)
 
##创建关系
#分别建立了test_node_1指向test_node_2和test_node_2指向test_node_1两条关系，关系的类型为"丈夫、妻子"，两条关系都有属性count，且值为1。
node_1_zhangfu_node_1 = Relationship(test_node_1,'丈夫',test_node_2)
node_1_zhangfu_node_1['count'] = 1
node_2_qizi_node_1 = Relationship(test_node_2,'妻子',test_node_1)
node_2_munv_node_1 = Relationship(test_node_2,'母女',test_node_3)
 
node_2_qizi_node_1['count'] = 1
 
graph.create(node_1_zhangfu_node_1)
graph.create(node_2_qizi_node_1)
graph.create(node_2_munv_node_1)
 
print(graph)
print(test_node_1)
print(test_node_2)
print(node_1_zhangfu_node_1)
print(node_2_qizi_node_1)
print(node_2_munv_node_1)
# Out:
# <Graph database=<Database uri='http://localhost:7474' secure=False user_agent='py2neo/4.3.0 urllib3/1.24.3 Python/3.8.2-final-0 (linux)'> name='data'>
# (_2 {label: 'ru_yi_zhuan', name: '\u7687\u5e1d'})
# (_3 {label: 'ru_yi_zhuan', name: '\u7687\u540e'})
# (皇帝)-[:丈夫 {count: 1}]->(皇后)
# (皇后)-[:妻子 {count: 1}]->(皇帝)
# (皇后)-[:母女 {}]->(公主)

# %% [markdown]
# 用csv导入的话需要先生成csv文件。LABEL上可以再下功夫，比如引入jieba。

# %%
import pandas as pd
import csv
from pandas.core.frame import DataFrame

# 抽取三元组, 去除重复实体
# subject主体，object目标，action动作
rels = [{'_conf_score': 0.41557023, 'action': '是指', 'object': '完整的描述', 'subject': '算法：', 'type': 'action'}, {'_conf_score': 0.41557023, 'action': '是指', 'object': '解题方案', 'subject': '算法：', 'type': 'action'}, {'_conf_score': 0.5452929, 'action': '不可能优于', 'object': '算法的设计', 'subject': '程序的编制', 'type': 'action'}, {'_conf_score': 0.507533, 'action': '都必须有', 'object': '明确定义', 'subject': '算法中每一步骤', 'type': 'action'}, {'_conf_score': 0.4241477, 'action': '都必须有', 'object': '确定性', 'subject': '算法中每一步骤', 'type': 'state'}, {'_conf_score': 0.41979942, 'action': '是', 'object': '对数据对象的运算和操作', 'subject': '算法的基本要素：', 'type': 'state'}, {'_conf_score': 0.41979942, 'action': '是', 'object': '算法的控制结构', 'subject': '算法的基本要素：', 'type': 'state'}, {'_conf_score': 0.48183978, 'action': '包括', 'object': '算术运算、逻辑运算、关系运算、数据传输', 'subject': '基本运算', 'type': 'action'}, {'_conf_score': 0.38296872, 'action': '选择', 'object': '结构、循环结构', 'subject': '顺序结构、', 'type': 'action'}, {'_conf_score': 0.51243323, 'action': '是指执行', 'object': '需要的内存空间', 'subject': '算法空间复杂度', 'type': 'action'}, {'_conf_score': 0.47507197, 'action': '是指执行', 'object': '这个算法', 'subject': '算法空间复杂度', 'type': 'action'}, {'_conf_score': 0.52690953, 'action': '是指', 'object': '相互有关联的数据元素的集合', 'subject': '数据结构', 'type': 'action'}, {'_conf_score': 0.57437533, 'action': '有', 'object': '顺序、链接、索引', 'subject': '数据的存储结构', 'type': 'action'}, {'_conf_score': 0.56926626, 'action': '有', 'object': '一个前件', 'subject': '每一个结点', 'type': 'action'}, {'_conf_score': 0.58278406, 'action': '也最多有', 'object': '一个后件', 'subject': '每一个结点', 'type': 'action'}, {'_conf_score': 0.50802267, 'action': '不满足', 'object': '线性结构条件的数据结构', 'subject': '非线性结构', 'type': 'action'}, {'_conf_score': 0.49789006, 'action': '只取决于', 'object': '自己的序号', 'subject': '数据元素的位置', 'type': 'action'}, {'_conf_score': 0.5246107, 'action': '是', 'object': '线性的', 'subject': '元素之间的相对位置', 'type': 'state'}, {'_conf_score': 0.50764674, 'action': '称为', 'object': '记录', 'subject': '组成的数据元素', 'type': 'action'}, {'_conf_score': 0.5127271, 'action': '又称为', 'object': '文件', 'subject': '多个记录构成的线性表', 'type': 'action'}, {'_conf_score': 0.2625839, 'action': '称为', 'object': '空表', 'subject': '结点个数n称为线性表的长度', 'type': 'action'}, {'_conf_score': 0.6279738, 'action': '具有', 'object': '以下两个基本特点', 'subject': '线性表的顺序存储结构', 'type': 'action'}, {'_conf_score': 0.4429372, 'action': '是', 'object': '连续的', 'subject': '线性表中所有元素的所占的存储空间', 'type': 'state'}, {'_conf_score': 0.25017223, 'action': '是', 'object': '顺序依次存放的', 'subject': '线性表中各数据元素', 'type': 'state'}, {'_conf_score': 0.49323758, 'action': '代表', 'object': '每个元素占的字节数', 'subject': 'ai的存储地址', 'type': 'action'}, {'_conf_score': 0.50032717, 'action': '为', 'object': '第一个元素的地址', 'subject': 'ADR', 'type': 'state'}, {'_conf_score': 0.5761316, 'action': '包括', 'object': '退队运算', 'subject': '队列运算', 'type': 'action'}, {'_conf_score': 0.5761316, 'action': '删除', 'object': '一个元素', 'subject': '队列运算', 'type': 'action'}, {'_conf_score': 0.41138476, 'action': '对应', 'object': '简称结点', 'subject': '数据结构中的每一个结点', 'type': 'action'}, {'_conf_score': 0.5245295, 'action': '即可用于表示', 'object': '线性结构', 'subject': '链式存储方式', 'type': 'action'}, {'_conf_score': 0.52518404, 'action': '也可用于表示', 'object': '非线性结构', 'subject': '链式存储方式', 'type': 'action'}, {'_conf_score': 0.47711527, 'action': '称为', 'object': '该结点的度', 'subject': '拥有的后件的个数', 'type': 'action'}, {'_conf_score': 0.47140625, 'action': '称为', 'object': '树的度', 'subject': '最大的度', 'type': 'action'}, {'_conf_score': 0.5295174, 'action': '称为', 'object': '树的深度', 'subject': '树的最大层次', 'type': 'action'}, {'_conf_score': 0.3570994, 'action': '有', 'object': '两棵子树', 'subject': '二叉树的特点：', 'type': 'action'}, {'_conf_score': 0.52470917, 'action': '有', 'object': '两棵子树', 'subject': '每一个结点', 'type': 'action'}, {'_conf_score': 0.48605505, 'action': '为', 'object': '根结点', 'subject': '该结点', 'type': 'state'}, {'_conf_score': 0.5162696, 'action': '为', 'object': 'INT', 'subject': '该结点的父结点编号', 'type': 'state'}, {'_conf_score': 0.5091029, 'action': '为', 'object': '2k', 'subject': 'k的结点的左子结点编号', 'type': 'state'}, {'_conf_score': 0.51946896, 'action': '无', 'object': '右子结点', 'subject': '该结点', 'type': 'action'}, {'_conf_score': 0.51162654, 'action': '为', 'object': '2k+1', 'subject': 'k的结点的右子结点编号', 'type': 'state'}, {'_conf_score': 0.4814384, 'action': '有', 'object': '两个子结点', 'subject': '每一层上的所有结点', 'type': 'action'}, {'_conf_score': 0.49839222, 'action': '有', 'object': '2m-1个结点', 'subject': '满二叉树', 'type': 'action'}, {'_conf_score': 0.46897963, 'action': '是', 'object': '指除', 'subject': '满二叉树', 'type': 'state'}, {'_conf_score': 0.49993157, 'action': '均达到', 'object': '最大值', 'subject': '每一层上的结点数', 'type': 'num'}, {'_conf_score': 0.50040805, 'action': '采用', 'object': '链式存储结构', 'subject': '二叉树存储结构', 'type': 'action'}, {'_conf_score': 0.51493055, 'action': '只需', 'object': '比较log2n次', 'subject': '最坏情况', 'type': 'num'}, {'_conf_score': 0.5180838, 'action': '需要', 'object': 'O次比较。', 'subject': '最坏情况', 'type': 'action'}, {'_conf_score': 0.4297427, 'action': '需要', 'object': 'O次比较。', 'subject': '希尔排序法', 'type': 'action'}, {'_conf_score': 0.45802248, 'action': '文档化', 'object': ' 2、数据说明的方法', 'subject': '1、源程序', 'type': 'action'}, {'_conf_score': 0.4288851, 'action': '执行', 'object': '相应的语句序列', 'subject': '哪一条分支', 'type': 'action'}, {'_conf_score': 0.500564, 'action': '为', 'object': '标志', 'subject': '末挪威奥斯陆大学和挪威计算机中心研制的SIMULA语言', 'type': 'state'}, {'_conf_score': 0.57899, 'action': '包括', 'object': '多个参数', 'subject': '消息的组成', 'type': 'action'}, {'_conf_score': 0.5617712, 'action': '包括', 'object': '零个', 'subject': '消息的组成', 'type': 'action'}, {'_conf_score': 0.4219998, 'action': '只允许有', 'object': '一个父类', 'subject': '继承分单继承和多重继承', 'type': 'action'}, {'_conf_score': 0.48757035, 'action': '只允许有', 'object': '一个父类', 'subject': '单继承', 'type': 'action'}, {'_conf_score': 0.4219998, 'action': '只允许有', 'object': '一个类', 'subject': '继承分单继承和多重继承', 'type': 'state'}, {'_conf_score': 0.4637962, 'action': '只允许有', 'object': '一个类', 'subject': '单继承', 'type': 'state'}, {'_conf_score': 0.48564562, 'action': '是包括', 'object': '程序、数据及相关文档的完整集合', 'subject': '计算机软件', 'type': 'action'}, {'_conf_score': 0.56716, 'action': '没有', 'object': '明显的制作过程', 'subject': '软件的生产与硬件', 'type': 'action'}, {'_conf_score': 0.47778073, 'action': '具有', 'object': '依赖性', 'subject': '软件的开发、运行', 'type': 'action'}, {'_conf_score': 0.47778073, 'action': '受', 'object': '计算机系统的限制', 'subject': '软件的开发、运行', 'type': 'action'}, {'_conf_score': 0.47778073, 'action': '导致了', 'object': '软件移植的问题', 'subject': '软件的开发、运行', 'type': 'action'}, {'_conf_score': 0.65097463, 'action': '涉及', 'object': '诸多的社会因素', 'subject': '软件开发', 'type': 'action'}, {'_conf_score': 0.59724706, 'action': '实践', 'object': '标准和工序', 'subject': '软件工程', 'type': 'action'}, {'_conf_score': 0.5804506, 'action': '包括', 'object': '方法、工具和过程', 'subject': '软件工程', 'type': 'action'}, {'_conf_score': 0.504634, 'action': '包括', 'object': '3个要素', 'subject': '软件工程', 'type': 'action'}, {'_conf_score': 0.55014163, 'action': '包含', 'object': '4种基本活动', 'subject': '软件工程过程', 'type': 'action'}, {'_conf_score': 0.42436206, 'action': '付出', 'object': '较低的开发成本', 'subject': '基本目标：', 'type': 'action'}, {'_conf_score': 0.42436206, 'action': '达到', 'object': '要求的软件功能', 'subject': '基本目标：', 'type': 'action'}, {'_conf_score': 0.601393, 'action': '主要包括', 'object': '软件开发技术和软件工程管理', 'subject': '软件工程的理论和技术性研究的内容', 'type': 'action'}, {'_conf_score': 0.5740379, 'action': '包括', 'object': '软件开发方法学、开发过程、开发工具和软件工程环境', 'subject': '软件开发技术', 'type': 'action'}, {'_conf_score': 0.56561476, 'action': '包括', 'object': '内容', 'subject': '软件工程管理', 'type': 'action'}, {'_conf_score': 0.48590505, 'action': '包括', 'object': '配置管理、项目计划', 'subject': '软件管理学', 'type': 'action'}, {'_conf_score': 0.38695285, 'action': '包括', 'object': '、局部化、确定性、一致性、完备性和可验证性', 'subject': '软件工程原则', 'type': 'action'}, {'_conf_score': 0.6699601, 'action': '化', 'object': '分析方法', 'subject': '3．2 结构', 'type': 'action'}, {'_conf_score': 0.60984194, 'action': '有', 'object': '面向对象的分析的方法', 'subject': '需求分析方法', 'type': 'action'}, {'_conf_score': 0.49036998, 'action': '是确定', 'object': '系统的物理模型', 'subject': '软件设计', 'type': 'action'}, {'_conf_score': 0.5124948, 'action': '是', 'object': '开发阶段最重要的步骤', 'subject': '软件设计', 'type': 'state'}, {'_conf_score': 0.52449036, 'action': '是', 'object': '转化为完整的软件产品或系统的唯一途径', 'subject': '软件设计', 'type': 'state'}, {'_conf_score': 0.4088159, 'action': '转换成', 'object': '软件的过程描述', 'subject': '过程设计：', 'type': 'action'}, {'_conf_score': 0.39835775, 'action': '先进行', 'object': '高层次的结构设计', 'subject': '软件设计的一般过程：', 'type': 'action'}, {'_conf_score': 0.47753674, 'action': '先进行', 'object': '高层次的结构设计', 'subject': '软件设计', 'type': 'action'}, {'_conf_score': 0.39835775, 'action': '进行', 'object': '数据设计和接口设计', 'subject': '软件设计的一般过程：', 'type': 'action'}, {'_conf_score': 0.5013546, 'action': '进行', 'object': '数据设计和接口设计', 'subject': '软件设计', 'type': 'action'}, {'_conf_score': 0.39835775, 'action': '是', 'object': '一个迭代的过程', 'subject': '软件设计的一般过程：', 'type': 'state'}, {'_conf_score': 0.50532687, 'action': '是', 'object': '一个迭代的过程', 'subject': '软件设计', 'type': 'state'}, {'_conf_score': 0.53913575, 'action': '应', 'object': '高内聚', 'subject': '优秀软件', 'type': 'action'}, {'_conf_score': 0.48299125, 'action': '是控制', 'object': '信息', 'subject': '传递的', 'type': 'action'}, {'_conf_score': 0.49392077, 'action': '有', 'object': '四种模块类型', 'subject': '结构图', 'type': 'action'}, {'_conf_score': 0.35052925, 'action': '有', 'object': '传入模块', 'subject': '结构图', 'type': 'action'}, {'_conf_score': 0.5466472, 'action': '传出', 'object': '模块', 'subject': '结构图', 'type': 'action'}, {'_conf_score': 0.5753116, 'action': '有', 'object': '变换型和事务型', 'subject': '典型的数据流类型', 'type': 'action'}, {'_conf_score': 0.5411707, 'action': '有', 'object': '两种', 'subject': '典型的数据流类型', 'type': 'action'}, {'_conf_score': 0.31885734, 'action': '运行', 'object': '测定某个系统的过程', 'subject': '使用人工或自动手段', 'type': 'action'}, {'_conf_score': 0.4737866, 'action': '在于', 'object': '检验', 'subject': '其目的', 'type': 'action'}, {'_conf_score': 0.4877863, 'action': '发现', 'object': '执行程序的过程', 'subject': '软件测试的目的：', 'type': 'action'}, {'_conf_score': 0.4877863, 'action': '发现', 'object': '错误', 'subject': '软件测试的目的：', 'type': 'action'}, {'_conf_score': 0.47939372, 'action': '有', 'object': '逻辑覆盖、基本基路径测试', 'subject': '主要方法', 'type': 'action'}, {'_conf_score': 0.5163628, 'action': '进行', 'object': '单元测试、集成测试、验收测试和系统测试', 'subject': '软件测试过程', 'type': 'action'}, {'_conf_score': 0.5329777, 'action': '是', 'object': '诊断和改正程序中的错误', 'subject': '程序调试的任务', 'type': 'state'}, {'_conf_score': 0.40540314, 'action': '是', 'object': '分析源程序代码和排错', 'subject': '分表静态调试和动态调试', 'type': 'state'}, {'_conf_score': 0.40540314, 'action': '是', 'object': '主要的设计手段', 'subject': '分表静态调试和动态调试', 'type': 'state'}, {'_conf_score': 0.43128312, 'action': '是', 'object': '分析源程序代码和排错', 'subject': '静态调试', 'type': 'state'}, {'_conf_score': 0.45615268, 'action': '是', 'object': '主要的设计手段', 'subject': '静态调试', 'type': 'state'}, {'_conf_score': 0.43850362, 'action': '是', 'object': '辅助静态调试', 'subject': '动态调试', 'type': 'state'}, {'_conf_score': 0.4885074, 'action': '实际上就是描述', 'object': '事物的符号记录', 'subject': '数据：', 'type': 'action'}, {'_conf_score': 0.3449823, 'action': '有', 'object': '如整型、实型、字符型', 'subject': '数据的特点：', 'type': 'action'}, {'_conf_score': 0.46461055, 'action': '有', 'object': '有型与值之分', 'subject': '数据的特点：', 'type': 'action'}, {'_conf_score': 0.46630555, 'action': '有', 'object': '一定的结构', 'subject': '数据的特点：', 'type': 'action'}, {'_conf_score': 0.5086673, 'action': '给出了符合', 'object': '定型的值', 'subject': '数据的值', 'type': 'action'}, {'_conf_score': 0.46630555, 'action': '值', 'object': '15', 'subject': '数据的特点：', 'type': 'num'}, {'_conf_score': 0.4627863, 'action': '具有', 'object': '统一的结构形式', 'subject': '数据库：', 'type': 'action'}, {'_conf_score': 0.47254622, 'action': '是', 'object': '数据的集合', 'subject': '数据库：', 'type': 'state'}, {'_conf_score': 0.42706513, 'action': '是', 'object': '可被各个应用程序共享', 'subject': '数据库：', 'type': 'state'}, {'_conf_score': 0.47254622, 'action': '是', 'object': '多种应用数据的集成', 'subject': '数据库：', 'type': 'state'}, {'_conf_score': 0.52514887, 'action': '放', 'object': '数据', 'subject': '数据库存', 'type': 'action'}, {'_conf_score': 0.5482067, 'action': '具有', 'object': '集成与共享的特点', 'subject': '数据库存', 'type': 'action'}, {'_conf_score': 0.39961, 'action': '是', 'object': '数据库中的数据组织、数据操纵、数据维护、控制及保护和数据服务', 'subject': '一种系统软件', 'type': 'state'}, {'_conf_score': 0.4229059, 'action': '是', 'object': '数据库的核心', 'subject': '一种系统软件', 'type': 'state'}, {'_conf_score': 0.51911837, 'action': '提供', 'object': '有效的存取方法与手段', 'subject': '为数据模式的物理存取与构建', 'type': 'action'}, {'_conf_score': 0.4448604, 'action': '使用', 'object': '数据库的数据', 'subject': '数据操纵：', 'type': 'action'}, {'_conf_score': 0.29801437, 'action': '提供', 'object': '简单的算术运算及统计', 'subject': '数据操纵：', 'type': 'action'}, {'_conf_score': 0.54230803, 'action': '提供', 'object': '以下的数据语言', 'subject': '数据库管理系统', 'type': 'action'}, {'_conf_score': 0.51474315, 'action': '使用', 'object': '方式', 'subject': '数据语言', 'type': 'action'}, {'_conf_score': 0.51474315, 'action': '具有', 'object': '交互式命令和宿主型语言', 'subject': '数据语言', 'type': 'action'}, {'_conf_score': 0.4885069, 'action': '具有', 'object': '两种结构形式：', 'subject': '数据语言', 'type': 'action'}, {'_conf_score': 0.4563376, 'action': '进行', 'object': '规划、设计', 'subject': '数据库管理员：', 'type': 'action'}, {'_conf_score': 0.4563376, 'action': '进行', 'object': '专业管理人员', 'subject': '数据库管理员：', 'type': 'action'}, {'_conf_score': 0.48112416, 'action': '共享', 'object': '数据管理能力', 'subject': '简单的数据', 'type': 'action'}, {'_conf_score': 0.43554142, 'action': '无法提供完整', 'object': '、统一的、管理和数据共享的能力', 'subject': '简单的数据', 'type': 'action'}, {'_conf_score': 0.48755738, 'action': '又称', 'object': '物理模式', 'subject': '内模式：', 'type': 'action'}, {'_conf_score': 0.48755738, 'action': '给出了', 'object': '数据库物理存储结构与物理存取方法', 'subject': '内模式：', 'type': 'action'}, {'_conf_score': 0.674982, 'action': '到', 'object': '内模式的映射', 'subject': '概念模式', 'type': 'action'}, {'_conf_score': 0.47961652, 'action': '可取属', 'object': '性域内的值', 'subject': '每个实体', 'type': 'action'}, {'_conf_score': 0.53597176, 'action': '叫', 'object': '元组', 'subject': '一个实体的所有属性值', 'type': 'action'}, {'_conf_score': 0.6102467, 'action': '具有', 'object': '以下特点', 'subject': '层次模型的基本结构', 'type': 'action'}, {'_conf_score': 0.5962288, 'action': '是', 'object': '树形结构', 'subject': '层次模型的基本结构', 'type': 'state'}, {'_conf_score': 0.5145761, 'action': '有且仅有', 'object': '一个无双亲结点', 'subject': '每棵树', 'type': 'action'}, {'_conf_score': 0.5037559, 'action': '是', 'object': '一个不加任何条件限制的无向图', 'subject': '网状模型', 'type': 'state'}, {'_conf_score': 0.45507824, 'action': '表示', 'object': '简称表', 'subject': '二维表来', 'type': 'action'}, {'_conf_score': 0.5416373, 'action': '就是', 'object': '一个关系', 'subject': '一个二维表', 'type': 'state'}, {'_conf_score': 0.62571263, 'action': '不能为', 'object': '空值', 'subject': '约束关系的主键中属性值', 'type': 'action'}, {'_conf_score': 0.45626983, 'action': '反映了', 'object': '具体应用中数据的语义要求', 'subject': '用户定义的完整性约束：', 'type': 'action'}, {'_conf_score': 0.45626983, 'action': '反映了', 'object': '4.3关系代数', 'subject': '用户定义的完整性约束：', 'type': 'action'}, {'_conf_score': 0.45564762, 'action': '可以表示', 'object': '关系模型的数据操作', 'subject': '很多数据理论', 'type': 'action'}, {'_conf_score': 0.4813336, 'action': '是', 'object': '关系代数与关系演算', 'subject': '其中最为著名的', 'type': 'state'}, {'_conf_score': 0.65818346, 'action': '是', 'object': '数据应用的核心', 'subject': '数据库设计', 'type': 'state'}, {'_conf_score': 0.49751753, 'action': '兼顾', 'object': '信息需求', 'subject': '面向过程', 'type': 'action'}, {'_conf_score': 0.48406154, 'action': '包括', 'object': '数据项、数据结构、数据流、数据存储、处理过程', 'subject': '数据字典', 'type': 'action'}, {'_conf_score': 0.51828873, 'action': '是', 'object': '各类数据描述的集合', 'subject': '数据字典', 'type': 'state'}, {'_conf_score': 0.48808703, 'action': '是分析', 'object': '数据内在语义关系', 'subject': '数据库概念设计的目的', 'type': 'action'}, {'_conf_score': 0.48619705, 'action': '一般有', 'object': '三种设计次序：', 'subject': '视图设计', 'type': 'action'}, {'_conf_score': 0.4079937, 'action': '约束', 'object': '冲突', 'subject': '冲突、概念冲突、域冲突', 'type': 'action'}, {'_conf_score': 0.49366742, 'action': '有', 'object': '100分里30分的原题', 'subject': '这个里面', 'type': 'action'}]
entity = set()
h_r_t = {
    ':START_ID': [],
    ':END_ID': [],
    ':TYPE': []
}
for each in rels:
    entity.add(each['subject'])
    entity.add(each['object'])
    h_r_t[':START_ID'].append(each['subject'])
    h_r_t[':END_ID'].append(each['object'])
    h_r_t[':TYPE'].append(each['action'])
print(entity)
# 保存节点文件
csvf_entity = open("entity.csv", "w", newline='', encoding='utf-8')
w_entity = csv.writer(csvf_entity)
# 实体ID，要求唯一，名称，LABEL标签，可自己不同设定对应的标签
w_entity.writerow(("entity:ID", "name", ":LABEL"))
entity = list(entity)
entity_dict = {}
for i in range(len(entity)):
    w_entity.writerow(("e" + str(i), entity[i], "my_entity"))
    entity_dict[entity[i]] = "e"+str(i)
csvf_entity.close()
# 生成关系文件，起始实体ID，终点实体ID，要求与实体文件中ID对应，:TYPE即为关系
h_r_t = DataFrame(h_r_t)
h_r_t[':START_ID'] = h_r_t[':START_ID'].map(entity_dict)
h_r_t[':END_ID'] = h_r_t[':END_ID'].map(entity_dict)
h_r_t.to_csv("roles.csv", index=False)
# Out:
# {'顺序依次存放的', '确定性', '两棵子树', '零个', '、局部化、确定性、一致性、完备性和可验证性', '四种模块类型', '程序、数据及相关文档的完整集合', '主要方法', '以下的数据语言', '程序调试的任务', '每个实体', '队列运算', '层次模型的基本结构', '1、源程序', '单继承', '内模式：', '使用人工或自动手段', '100分里30分的原题', '明确定义', '数据：', '方法、工具和过程', '典型的数据流类型', '两个子结点', '二叉树存储结构', '一个后件', '算术运算、逻辑运算、关系运算、数据传输', '三种设计次序：', '标志', '动态调试', '哪一条分支', '冲突', '线性结构', '简单的算术运算及统计', '这个算法', '2k', '数据的值', '消息的组成', '数据项、数据结构、数据流、数据存储、处理过程', '如整型、实型、字符型', '数据结构', '数据库管理系统', '树的最大层次', '线性结构条件的数据结构', '规划、设计', '简称结点', '配置管理、项目计划', '数据语言', '很多数据理论', '明显的制作过程', '算法的基本要素：', '以下两个基本特点', '自己的序号', '内容', '一个迭代的过程', '基本运算', '软件的生产与硬件', '视图设计', 'k的结点的右子结点编号', '树形结构', '软件设计', '结构图', '网状模型', '结点个数n称为线性表的长度', '2m-1个结点', '需求分析方法', '数据应用的核心', '4.3关系代数', '多种应用数据的集成', '第一个元素的地址', '简称表', '分表静态调试和动态调试', '计算机系统的限制', '软件开发', '基本目标：', '一个关系', '拥有的后件的个数', '程序的编制', '每一个结点', '数据库管理员：', '数据结构中的每一个结点', '该结点的父结点编号', '2k+1', '为数据模式的物理存取与构建', '数据管理能力', '数据设计和接口设计', '软件工程过程', '软件工程管理', '二维表来', '每一层上的结点数', '信息需求', '非线性结构', '软件的开发、运行', '3．2 结构', 'O次比较。', '
# ...

# %% [markdown]
# 导入到neo4j

# %%
# !/home/lx/neo4j-community-4.0.3/bin/neo4j-admin import --nodes /home/lx/PycharmProjects/KG/entity.csv --relationships /home/lx/PycharmProjects/KG/roles.csv
# Out:
# Neo4j version: 4.0.3
# Importing the contents of these files into /home/lx/neo4j-community-4.0.3/data/databases/neo4j:
# Nodes:
#   /home/lx/PycharmProjects/KG/entity.csv
#
# Relationships:
#   /home/lx/PycharmProjects/KG/roles.csv
#
#
# Available resources:
#   Total machine memory: 6.771GiB
#   Free machine memory: 1.078GiB
#   Max heap memory : 1.505GiB
#   Processors: 8
#   Configured max memory: 4.739GiB
#   High-IO: false
#
#
# Import starting 2020-05-01 02:01:29.502+0800
#   Estimated number of nodes: 393.00
#   Estimated number of node properties: 786.00
#   Estimated number of relationships: 209.00
#   Estimated number of relationship properties: 0.00
#   Estimated disk space usage: 41.50KiB
#   Estimated required memory usage: 1020MiB
#
# (1/4) Node import 2020-05-01 02:01:29.585+0800
#   Estimated number of nodes: 393.00
#   Estimated disk space usage: 34.56KiB
#   Estimated required memory usage: 1020MiB
# -......... .......... .......... .......... ..........   5% ∆74ms
# ...

# %% [markdown]
# # KBQA——构建QA系统

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 是考虑结合深度学习还是手工构建模板规则？
# 首先必须考虑的是关系。KB中的现有关系（即action）必须通过神经网络算法进行近义处理。
# 知识抽取上应改用更为强大且开源的DeepDive（暂时在用smoothnlp，感觉虽然是国产但是很少人用）。对于文档标题考虑神经网络或规则抽取。
# https://linux.ctolib.com/Pelhans-Z_knowledge_graph.html

# %%
from smoothnlp import kg
strs = ["数据结构是指什么东西"]
# strs = ["队列运算包括什么？"]
rels = kg.extract(strs)  ## 调用SmoothNLP解析
print(rels)
# Out:
# [{'_conf_score': 0.6291617, 'action': '是指', 'object': '什么东西', 'subject': '数据结构', 'type': 'action'}]

# %%
from py2neo import Graph,Node,Relationship
import pandas as pd
graph = Graph("http://localhost:7474/db/data/", username="neo4j", password="7890")
match_str = "MATCH (subject)-[:{}]-(object)  WHERE subject.name = '{}' RETURN object.name".format(rels[0]['action'],rels[0]['subject'])
# match_str="MATCH (subject)-[:是指]-(object) WHERE subject.name = '数据结构' RETURN object.name"
# tmp_df = pd.DataFrame(graph.run(match_str))
p1 = graph.run(match_str).data()
# graph.run().data()               # a list of dictionary
# graph.run().to_data_frame()      # pd.DataFrame
# graph.run().to_ndarray()         # numpy.ndarray
# graph.run().to_subgraph()
# graph.run().to_table()

for record in p1:
    print(record['object.name']+'\n')
# Out:
# 相互有关联的数据元素的集合

# %% [markdown]
# MATCH (subject)-[:是指]-(object)
# WHERE subject.name = '数据结构'
# RETURN object.name
